# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


# %matplotlib inline

# %%
data=pd.read_csv('moscow_apartment_listings.csv')
data
# Out:
#           price  repair  year_built_empty  house_age  closest_subway  \
# 0       8000000       3                 0         42              59
# 1       7200000       2                 0         43              59
# 2      10300000       2                 0         43              59
# 3       8500000       2                 0         43              59
# 4       9000000       2                 0         43              59
# ...         ...     ...               ...        ...             ...
# 12176   8700000       2                 0         47             135
# 12177   9450000       2                 0         31             135
# 12178  19000000       4                 0         19             135
# 12179  16900000       1                 0         19             135
# 12180  17330000       2                 0         91              67
#
#        dist_to_subway   sg        lat        lon  subway_dist_to_center  ...  \
# 0                 960  0.0  55.609009  37.734632                  17166  ...
# 1                 802  0.0  55.608760  37.741936                  17166  ...
# 2                 638  0.0  55.610207  37.742495                  17166  ...
# 3                 929  0.0  55.624017  37.740373                  17166  ...
# 4                 785  0.0  55.609107  37.740430                  17166  ...
# ...               ...  ...        ...        ...                    ...  ...
# 12176             423  2.0  55.813536  37.470033                  11088  ...
# 12177             581  2.0  55.809024  37.475441                  11088  ...
# 12178             842  2.0  55.817794  37.464824                  11088  ...
# 12179             842  2.0  55.817794  37.464824                  11088  ...
# 12180             733  0.0  55.759138  37.642292                   1133  ...
#
#       subway_offers  address_offers  rooms  footage  floor  max_floor  \
# 0                 5             1.0      1     39.4     11         12
# 1                 9             1.0      1     35.6      2          9
# 2                 9             2.0      2     53.0      5         12
# 3                 5             1.0      2     44.1      8          9
# 4                 5             1.0      2     44.2      6          9
# ...             ...             ...    ...      ...    ...        ...
# 12176             1             1.0      1     36.2      2         17
# 12177             2             1.0      1     38.3      6         22
# 12178             2             1.0      1     55.8     11         17
# 12179             1             1.0      2     62.0     15         17
# 12180             1             1.0      2     43.7      1          6
#
#        first_floor  last_floor    AO        hm
# 0                0           0   UAO     panel
# 1                0           0   UAO     panel
# 2                0           0   UAO     panel
# 3                0           0   UAO     panel
# 4                0           0   UAO     panel
# ...            ...         ...   ...       ...
# 12176            0           0  SZAO  monolith
# 12177            0           0  SZAO     panel
# 12178            0           0  SZAO  monolith
# 12179            0           0  SZAO  monolith
# 12180            1           0   CAO     brick
#
# [12181 rows x 22 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (12181, 22)

# %%
data.AO.value_counts()
# Out:
# UVAO    2053
# ZAO     1594
# UAO     1496
# UZAO    1453
# SAO     1422
# SVAO    1388
# VAO     1362
# SZAO     760
# CAO      653
# Name: AO, dtype: int64

# %%
data.hm.value_counts()
# Out:
# panel       5731
# brick       2483
# monolith    2378
# block       1589
# Name: hm, dtype: int64

# %%
pd.isnull(data).any()
# Out:
# price                    False
# repair                   False
# year_built_empty         False
# house_age                False
# closest_subway           False
# dist_to_subway           False
# sg                       False
# lat                      False
# lon                      False
# subway_dist_to_center    False
# h3                       False
# agent_offers             False
# subway_offers            False
# address_offers           False
# rooms                    False
# footage                  False
# floor                    False
# max_floor                False
# first_floor              False
# last_floor               False
# AO                       False
# hm                       False
# dtype: bool

# %%
data.describe()
# Out:
#               price        repair  year_built_empty     house_age  \
# count  1.218100e+04  12181.000000      12181.000000  12181.000000
# mean   1.086987e+07      2.267302          0.013710     36.360644
# std    3.037320e+06      0.787196          0.116289     21.406406
# min    4.900000e+06      1.000000          0.000000      0.000000
# 25%    8.500000e+06      2.000000          0.000000     17.000000
# 50%    1.020000e+07      2.000000          0.000000     42.000000
# 75%    1.270000e+07      3.000000          0.000000     54.000000
# max    2.000000e+07      4.000000          1.000000    130.000000
#
#        closest_subway  dist_to_subway            sg           lat  \
# count    12181.000000    12181.000000  12181.000000  12181.000000
# mean       100.585009      928.353748      0.242673     55.738639
# std         56.707817      532.443508      0.629897      0.087598
# min          0.000000       11.000000      0.000000     55.527631
# 25%         55.000000      548.000000      0.000000     55.674840
# 50%        103.000000      820.000000      0.000000     55.730856
# 75%        149.000000     1177.000000      0.000000     55.806115
# max        199.000000     2988.000000      3.000000     55.941577
#
#                 lon  subway_dist_to_center  agent_offers  subway_offers  \
# count  12181.000000           12181.000000  12181.000000   12181.000000
# mean      37.618241           11938.048026     25.429932      10.176915
# std        0.134112            4711.729983     61.837916       7.078888
# min       37.306055            1133.000000      0.000000       1.000000
# 25%       37.520435            8635.000000      1.000000       5.000000
# 50%       37.604411           12418.000000      1.000000       8.000000
# 75%       37.720789           14800.000000     11.000000      13.000000
# max       37.950668           24636.000000    292.000000      40.000000
#
#        address_offers         rooms       footage         floor     max_floor  \
# count    12181.000000  12181.000000  12181.000000  12181.000000  12181.000000
# mean         1.290124      1.603973     46.153803      6.867334     13.449306
# std          0.730561      0.489090     10.543171      5.313950      6.413437
# min          1.000000      1.000000     30.100000      1.000000      2.000000
# 25%          1.000000      1.000000     38.000000      3.000000      9.000000
# 50%          1.000000      2.000000     44.500000      5.000000     12.000000
# 75%          1.000000      2.000000     53.400000      9.000000     17.000000
# max          9.000000      2.000000     89.900000     38.000000     39.000000
#
#         first_floor    last_floor
# count  12181.000000  12181.000000
# mean       0.104671      0.094409
# std        0.306142      0.292409
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max        1.000000      1.000000

# %%
plt.figure(figsize=(16, 10))
plt.hist(data['price'], bins=50, ec='black')
plt.xlabel('Price in roubles P')
plt.ylabel('Number of appartments')
plt.show()

# %% [markdown]
# ### Geographical Data

# %%
data.plot(kind='scatter', x='lat', y='lon')
# Out:
# <AxesSubplot:xlabel='lat', ylabel='lon'>

# %%
data.plot(kind="scatter", x="lat", y="lon", alpha=0.4, s=data["rooms"], 
            label="rooms", c="price", cmap=plt.get_cmap("jet"), colorbar=True)
plt.legend()

# %%
data.plot(kind="scatter", x="lat", y="lon", alpha=0.4, s=data["footage"], 
            label="footage", c="price", cmap=plt.get_cmap("jet"), colorbar=True)
plt.legend()

# %% [markdown]
# ## Correlation
# ## $$ \rho _{XY} = corr(X,Y)$$
# ## $$ -1.0 \leq \rho _{XY} \leq +1.0 $$

# %%
mask=np.zeros_like(data.corr())
triangle_indices=np.triu_indices_from(mask)
mask[triangle_indices]=True
mask

plt.figure(figsize=(16, 10))
sns.heatmap(data.corr(), mask=mask, annot=True, annot_kws={"size":8})
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
data.corr()
# Out:
#                           price    repair  year_built_empty  house_age  \
# price                  1.000000  0.164010          0.051416  -0.262411
# repair                 0.164010  1.000000         -0.070530  -0.038472
# year_built_empty       0.051416 -0.070530          1.000000  -0.001986
# house_age             -0.262411 -0.038472         -0.001986   1.000000
# closest_subway        -0.023419 -0.016339         -0.030985   0.025786
# dist_to_subway        -0.133671 -0.008918         -0.004648  -0.089263
# sg                    -0.085062 -0.012442          0.006135  -0.015728
# lat                    0.040003  0.004259          0.010304   0.087363
# lon                   -0.265155 -0.016068          0.027939   0.015226
# subway_dist_to_center -0.366405  0.023552         -0.028596  -0.385133
# agent_offers           0.016465  0.059237         -0.015011  -0.015272
# subway_offers         -0.172992 -0.003846          0.057792  -0.172487
# address_offers         0.171650 -0.044063          0.120365  -0.241992
# rooms                  0.396066 -0.008218         -0.007021   0.115085
# footage                0.689433  0.008575          0.042489  -0.314398
# floor                  0.224920  0.052678          0.032306  -0.451621
# max_floor              0.342601  0.062188          0.071551  -0.760865
# first_floor           -0.151585 -0.030256         -0.017250   0.193775
# last_floor            -0.067709 -0.004778         -0.021166   0.134920
#
#                        closest_subway  dist_to_subway        sg       lat  \
# price                       -0.023419       -0.133671 -0.085062  0.040003
# repair                      -0.016339       -0.008918 -0.012442  0.004259
# year_built_empty            -0.030985       -0.004648  0.006135  0.010304
# house_age                    0.025786       -0.089263 -0.015728  0.087363
# closest_subway               1.000000        0.010817 -0.016481 -0.074215
# dist_to_subway               0.010817        1.000000  0.050013  0.065855
# sg                          -0.016481        0.050013  1.000000  0.108401
# lat                         -0.074215        0.065855  0.108401  1.000000
# lon                         -0.097201        0.023899 -0.126096 -0.109230
# subway_dist_to_center        0.036289        0.115726  0.054405 -0.238450
# agent_offers                 0.011809       -0.015708 -0.018938 -0.013893
# subway_offers                0.022446        0.160898 -0.144005  0.036666
# address_offers              -0.036067       -0.046766  0.021837  0.002436
# rooms                        0.006211       -0.023967 -0.000359  0.006960
# footage                     -0.027841        0.009652 -0.025396 -0.030557
# floor                       -0.010780        0.030321 -0.012898 -0.016785
# max_floor                   -0.028875        0.041934 -0.019290 -0.042151
# first_floor                  0.014874       -0.029366 -0.004006 -0.003853
# last_floor                   0.005458        0.002989  0.003979  0.009956
#
#                             lon  subway_dist_to_center  agent_offers  \
# price                 -0.265155              -0.366405      0.016465
# repair                -0.016068               0.023552      0.059237
# year_built_empty       0.027939              -0.028596     -0.015011
# house_age              0.015226              -0.385133     -0.015272
# closest_subway        -0.097201               0.036289      0.011809
# dist_to_subway         0.023899               0.115726     -0.015708
# sg                    -0.126096               0.054405     -0.018938
# lat                   -0.109230              -0.238450     -0.013893
# lon                    1.000000               0.002178      0.006197
# subway_dist_to_center  0.002178               1.000000      0.019954
# agent_offers           0.006197               0.019954      1.000000
# subway_offers          0.370867               0.241462      0.025386
# address_offers        -0.026960              -0.004420      0.015062
# rooms                 -0.013513              -0.037015     -0.015992
# footage               -0.039559               0.061321     -0.015502
# floor                 -0.038598               0.141021      0.018663
# max_floor             -0.083484               0.213244      0.008433
# first_floor           -0.015948              -0.044529      0.001391
# last_floor             0.014894              -0.023479     -0.000910
#
#                        subway_offers  address_offers     rooms   footage  \
# price                      -0.172992        0.171650  0.396066  0.689433
# repair                     -0.003846       -0.044063 -0.008218  0.008575
# year_built_empty            0.057792        0.120365 -0.007021  0.042489
# house_age                  -0.172487       -0.241992  0.115085 -0.314398
# closest_subway              0.022446       -0.036067  0.006211 -0.027841
# dist_to_subway              0.160898       -0.046766 -0.023967  0.009652
# sg                         -0.144005        0.021837 -0.000359 -0.025396
# lat                         0.036666        0.002436  0.006960 -0.030557
# lon                         0.370867       -0.026960 -0.013513 -0.039559
# subway_dist_to_center       0.241462       -0.004420 -0.037015  0.061321
# agent_offers                0.025386        0.015062 -0.015992 -0.015502
# subway_offers               1.000000        0.086439 -0.000132  0.020500
# address_offers              0.086439        1.000000 -0.023998  0.138196
# rooms                      -0.000132       -0.023998  1.000000  0.652167
# footage                     0.020500        0.138196  0.652167  1.000000
# floor                       0.086231        0.169628 -0.062452  0.183433
# max_floor                   0.087217        0.239330 -0.107773  0.305038
# first_floor                -0.041543       -0.072283  0.003802 -0.087607
# last_floor                  0.003869       -0.021001  0.027229 -0.048159
#
#                           floor  max_floor  first_floor  last_floor
# price                  0.224920   0.342601    -0.151585   -0.067709
# repair                 0.052678   0.062188    -0.030256   -0.004778
# year_built_empty       0.032306   0.071551    -0.017250   -0.021166
# house_age             -0.451621  -0.760865     0.193775    0.134920
# closest_subway        -0.010780  -0.028875     0.014874    0.005458
# dist_to_subway         0.030321   0.041934    -0.029366    0.002989
# sg                    -0.012898  -0.019290    -0.004006    0.003979
# lat                   -0.016785  -0.042151    -0.003853    0.009956
# lon                   -0.038598  -0.083484    -0.015948    0.014894
# subway_dist_to_center  0.141021   0.213244    -0.044529   -0.023479
# agent_offers           0.018663   0.008433     0.001391   -0.000910
# subway_offers          0.086231   0.087217    -0.041543    0.003869
# address_offers         0.169628   0.239330    -0.072283   -0.021001
# rooms                 -0.062452  -0.107773     0.003802    0.027229
# footage                0.183433   0.305038    -0.087607   -0.048159
# floor                  1.000000   0.577713    -0.377541    0.204036
# max_floor              0.577713   1.000000    -0.193266   -0.162321
# first_floor           -0.377541  -0.193266     1.000000   -0.110399
# last_floor             0.204036  -0.162321    -0.110399    1.000000
